# %% [markdown]
# # RMIT RAG Evaluation — Retrieval + DeepEval
#
# This notebook covers:
#
# - **Retrieval:** Hit@3, Recall@3, NDCG@3
# - **DeepEval:** Answer Relevancy + Faithfulness
# - Persona-level summaries
# - Failure inspection
# - Progress saving after each DeepEval question
# - DeepEval sample: **4 per persona = 12 questions in total**

# %% [markdown]
# ## Evaluation Approach
#
# To evaluate the RAG system, we assess both **retrieval quality** and **generated answer quality**. This is important because a RAG system can fail at different stages: it may retrieve the wrong evidence, or it may retrieve the correct evidence but generate an inaccurate or unsupported answer.
#
# ### Retrieval Metrics
#
# Three complementary retrieval metrics are used:
#
# - **Hit@3** measures whether at least one relevant passage appears within the top three retrieved results. This provides a simple indication of whether the retriever is able to surface useful evidence for a query.
#
# - **Recall@3** measures the proportion of all relevant passages that are retrieved within the top three results. This is useful for identifying cases where the retriever finds some relevant evidence but misses other important supporting passages.
#
# - **NDCG@3** evaluates both relevance and ranking position. Relevant passages receive greater credit when they appear higher in the retrieved results, making this metric useful for assessing whether the most useful evidence is prioritised.
#
# These metrics were chosen together because they capture different aspects of retrieval performance: **Hit@3 measures presence, Recall@3 measures coverage, and NDCG@3 measures ranking quality**.
#
# ### Generation Metrics
#
# For answer generation, **DeepEval** is used to evaluate:
#
# - **Answer Relevancy** — whether the generated response directly addresses the user's question.
# - **Faithfulness** — whether the generated response is supported by the retrieved context rather than introducing unsupported information.
#
# DeepEval was selected because these metrics align closely with the main goals of a RAG system: responses should be both **relevant to the user's query** and **grounded in the retrieved source material**.
#
# Using DeepEval alongside retrieval metrics allows the system to be evaluated as a complete RAG pipeline rather than assessing retrieval or generation in isolation. This distinction is important because strong retrieval performance does not necessarily guarantee a correct final answer, and a well-written answer may still be unreliable if it is not supported by the retrieved evidence.

# %%
import os
import re
import time
import numpy as np
import pandas as pd
import ollama

from rank_bm25 import BM25Okapi

pd.set_option("display.max_colwidth", 140)

TOPICS_FILE = "topics_WIL20.csv"
PASSAGES_FILE = "passages_WIL20.csv"
QRELS_FILE = "qrels_WIL20.txt"

GENERATOR_MODEL = "llama3.2:3b"
JUDGE_MODEL = "qwen3:1.7b"

TOP_K = 3
DEEPEVAL_PER_PERSONA = 4
RANDOM_STATE = 42

os.environ["DEEPEVAL_PER_ATTEMPT_TIMEOUT_SECONDS_OVERRIDE"] = "180"
os.environ["DEEPEVAL_PER_TASK_TIMEOUT_SECONDS_OVERRIDE"] = "600"
os.environ["DEEPEVAL_RETRY_MAX_ATTEMPTS"] = "1"

# %% [markdown]
# ## 1. Load data

# %%
topics = pd.read_csv(TOPICS_FILE)
passages_df = pd.read_csv(PASSAGES_FILE)

qrels = pd.read_csv(
    QRELS_FILE,
    sep=r"\s+",
    header=None,
    names=["question_id", "unused", "passage_id", "relevance"]
)

print("Topics:", topics.shape)
print("Passages:", passages_df.shape)
print("Qrels:", qrels.shape)

display(topics.head())
display(passages_df.head())
display(qrels.head())
# Out:
# Topics: (70, 6)
# Passages: (45, 4)
# Qrels: (73, 4)
#   topic_id                                                   topic  \
# 0      C01              Can I study a Bachelor of Business online?
# 1      C01              Can I study a Bachelor of Business online?
# 2      C02  What career outcomes does the Marketing major lead to?
# 3      C02  What career outcomes does the Marketing major lead to?
# 4      C03                Can I enrol in advanced electives early?
#
#   question_id  \
# 0      C01Q01
# 1      C01Q02
# 2      C02Q01
# 3      C02Q02
# 4      C03Q01
#
#                                                                question  \
# 0                            Can I study a Bachelor of Business online?
# 1                    Is there an online version of the Business degree?
# 2                What career outcomes does the Marketing major lead to?
# 3            What jobs can students expect after majoring in Marketing?
# 4  Am I eligible to take a third-year elective as a first-year student?
#
#                persona status
# 0  prospective student  known
# 1      current student  known
# 2      parent/guardian  known
# 3      current student  known
# 4      current student  known
#   passage_id  \
# 0        P01
# 1        P02
# 2        P03
# 3        P04
# 4        P05
#
#                                                                                                                                        passage  \
# 0  The Bachelor of Business is available to study online at RMIT. The online Bachelor of Business takes 36 months to complete and offers fl...
# 1  The Marketing major prepares graduates for roles in digital marketing, brand management, campaign strategy, and customer analytics acros...
# 2  At RMIT, you can take a third-year elective as a first-year student as long as you meet the course requirements and your program structu...
# 3  When you successfully complete this degree, you may be eligible for entry into a range of RMIT Honours and postgraduate qualifications i...
# 4  The Bachelor of Graphic Design offers four majors: Branding, Experience Design, Illustration, and Typography. The Branding major focuses...
#
#                              school                     program
# 0  Economics, Finance and Marketing        Bachelor of Business
# 1  Economics, Finance and Marketing        Bachelor of Business
# 2  Economics, Finance and Marketing                     General
# 3  Economics, Finance and Marketing        Bachelor of Commerce
# 4                            Design  Bachelor of Graphic Design
#   question_id  unused passage_id  relevance
# 0      C01Q01       0        P01          2
# 1      C01Q01       0        P15          1
# 2      C01Q02       0        P01          2
# 3      C01Q02       0        P15          1
# 4      C02Q01       0        P02          2

# %% [markdown]
# # Part A — Retrieval

# %%
def tokenize(text):
    return re.findall(r"\b\w+\b", str(text).lower())

tokenised_passages = [
    tokenize(text)
    for text in passages_df["passage"].fillna("").tolist()
]

bm25 = BM25Okapi(tokenised_passages)

def retrieve_top_k(question, k=TOP_K):
    scores = bm25.get_scores(tokenize(question))
    top_indices = np.argsort(scores)[::-1][:k]

    return [
        {
            "rank": rank,
            "passage_id": passages_df.iloc[i]["passage_id"],
            "passage": passages_df.iloc[i]["passage"],
            "score": float(scores[i]),
        }
        for rank, i in enumerate(top_indices, start=1)
    ]

# %%
qrels_by_question = {}

for question_id, group in qrels.groupby("question_id"):
    qrels_by_question[question_id] = dict(
        zip(group["passage_id"], group["relevance"])
    )

def dcg(relevances):
    return sum(
        (2 ** rel - 1) / np.log2(rank + 2)
        for rank, rel in enumerate(relevances)
    )

def retrieval_metrics_for_question(question_id, question, k=TOP_K):
    judged = qrels_by_question.get(question_id)

    if not judged:
        return None

    retrieved = retrieve_top_k(question, k=k)
    retrieved_ids = [x["passage_id"] for x in retrieved]

    relevant_ids = {
        pid for pid, rel in judged.items()
        if rel > 0
    }

    hit = int(any(pid in relevant_ids for pid in retrieved_ids))

    recall = (
        len(set(retrieved_ids) & relevant_ids) / len(relevant_ids)
        if relevant_ids else np.nan
    )

    retrieved_rels = [
        int(judged.get(pid, 0))
        for pid in retrieved_ids
    ]

    ideal_rels = sorted(
        [int(rel) for rel in judged.values()],
        reverse=True
    )[:k]

    retrieved_rels += [0] * (k - len(retrieved_rels))
    ideal_rels += [0] * (k - len(ideal_rels))

    ideal_dcg = dcg(ideal_rels)

    ndcg = dcg(retrieved_rels) / ideal_dcg if ideal_dcg > 0 else np.nan

    return {
        "retrieved_passage_ids": retrieved_ids,
        f"hit@{k}": hit,
        f"recall@{k}": recall,
        f"ndcg@{k}": ndcg,
    }

# %%
retrieval_rows = []

for _, row in topics.iterrows():
    metrics = retrieval_metrics_for_question(
        row["question_id"],
        row["question"],
        k=TOP_K
    )

    if metrics is not None:
        retrieval_rows.append({
            "question_id": row["question_id"],
            "persona": row["persona"],
            "question": row["question"],
            **metrics
        })

retrieval_results = pd.DataFrame(retrieval_rows)

display(retrieval_results.head())
print("Evaluated questions:", len(retrieval_results))
# Out:
#   question_id              persona  \
# 0      C01Q01  prospective student
# 1      C01Q02      current student
# 2      C02Q01      parent/guardian
# 3      C02Q02      current student
# 4      C03Q01      current student
#
#                                                                question  \
# 0                            Can I study a Bachelor of Business online?
# 1                    Is there an online version of the Business degree?
# 2                What career outcomes does the Marketing major lead to?
# 3            What jobs can students expect after majoring in Marketing?
# 4  Am I eligible to take a third-year elective as a first-year student?
#
#   retrieved_passage_ids  hit@3  recall@3    ndcg@3
# 0       [P01, P16, P15]      1       1.0  0.963940
# 1       [P01, P16, P44]      1       0.5  0.826235
# 2       [P02, P32, P14]      1       1.0  1.000000
# 3       [P02, P04, P44]      1       1.0  1.000000
# 4       [P03, P19, P12]      1       1.0  1.000000
# Evaluated questions: 53

# %%
retrieval_summary = pd.DataFrame({
    "metric": [f"Hit@{TOP_K}", f"Recall@{TOP_K}", f"NDCG@{TOP_K}"],
    "score": [
        retrieval_results[f"hit@{TOP_K}"].mean(),
        retrieval_results[f"recall@{TOP_K}"].mean(),
        retrieval_results[f"ndcg@{TOP_K}"].mean(),
    ]
})

display(retrieval_summary.round(3))
# Out:
#      metric  score
# 0     Hit@3  0.774
# 1  Recall@3  0.717
# 2    NDCG@3  0.686

# %%
retrieval_by_persona = (
    retrieval_results
    .groupby("persona")[
        [f"hit@{TOP_K}", f"recall@{TOP_K}", f"ndcg@{TOP_K}"]
    ]
    .mean()
    .round(3)
)

display(retrieval_by_persona)
# Out:
#                      hit@3  recall@3  ndcg@3
# persona
# current student      0.947     0.868   0.850
# parent/guardian      0.692     0.654   0.599
# prospective student  0.667     0.619   0.591

# %%
hit_failures = retrieval_results[
    retrieval_results[f"hit@{TOP_K}"] == 0
].copy()

print("Hit@3 failures:", len(hit_failures))

display(
    hit_failures[
        ["question_id", "persona", "question", "retrieved_passage_ids"]
    ]
)
# Out:
# Hit@3 failures: 12
#    question_id              persona  \
# 6       C04Q01      parent/guardian
# 8       C05Q01  prospective student
# 9       C05Q02  prospective student
# 10      C06Q01  prospective student
# 12      C07Q01  prospective student
# 13      C07Q02      current student
# 15      C08Q02  prospective student
# 23      C14Q01  prospective student
# 24      C14Q02  prospective student
# 33      C23Q01      parent/guardian
# 34      C24Q01      parent/guardian
# 51      C50Q01      parent/guardian
#
#                                                                                     question  \
# 6             Does the Bachelor of Commerce prepare students for further postgraduate study?
# 8                           What majors can I choose from in the Bachelor of Graphic Design?
# 9                                        What courses does Bachelor of Graphic Design offer?
# 10  What career opportunities are available after completing the Bachelor of Graphic Design?
# 12                                                 What does the Bachelor of Games focus on?
# 13                                         What areas will I study in the Bachelor of Games?
# 15                    What English requirements do I need to meet for the Bachelor of Games?
# 23                 What software should I be expected to learn during the Bachelor of Games?
# 24               What software do I need to have in order to complete the Bachelor of games?
# 33                      Will students get any industry experience while completing Commerce?
# 34                                              How much does the Bachelor of Business cost?
# 51                  What careers can my child pursue after completing the Bachelor of Games?
#
#    retrieved_passage_ids
# 6        [P44, P20, P38]
# 8        [P40, P06, P41]
# 9        [P15, P25, P40]
# 10       [P44, P23, P40]
# 12       [P24, P32, P39]
# 13       [P20, P35, P43]
# 15       [P31, P18, P43]
# 23       [P16, P17, P44]
# 24       [P11, P18, P32]
# 33       [P33, P25, P20]
# 34       [P14, P32, P44]
# 51       [P44, P41, P06]

# %%
retrieval_results.to_csv("retrieval_evaluation_results.csv", index=False)
retrieval_summary.to_csv("retrieval_evaluation_summary.csv", index=False)
retrieval_by_persona.to_csv("retrieval_evaluation_by_persona.csv")

print("Retrieval results saved.")
# Out:
# Retrieval results saved.

# %% [markdown]
# # Part B — Generate answers for DeepEval

# %%
ABSTENTION_TEXT = (
    "I don't have enough information in the provided RMIT sources "
    "to answer this question."
)

def build_prompt(question, context_passages):
    context = "\n\n".join(context_passages)

    return f"""You are an RMIT university information assistant.

Answer the user's question using ONLY the RMIT information provided below.

Follow these rules carefully:

1. Read ALL provided passages before answering.

2. If a passage directly answers the question, use that information.
   Do NOT abstain when the answer is explicitly stated.

3. Prioritise the passage that most specifically matches the user's question.
   For example:
   - for part-time study, prioritise information specifically about part-time study;
   - for changing majors, prioritise information specifically about changing majors;
   - for a named program, only use information that applies to that program.

4. Preserve explicit statements exactly.
   Pay particular attention to:
   "can", "cannot", "must", "must not",
   "required", "not required",
   "eligible", "not eligible",
   "exempt", "not exempt",
   "full-time", and "part-time".

   Also preserve numerical information such as years, subjects, fees,
   scores, study loads, and durations.

5. Do not infer permission, eligibility, requirements, policies, predictions,
   comparisons, or outcomes from indirect or missing information.

   The absence of information does NOT mean the answer is "no".

6. ANSWER IN A COMPLETE SENTENCE
   Give a direct, self-contained answer to the user's question.

   Do not respond with only "Yes" or "No".

   For yes-or-no questions, clearly state whether the answer is yes or no,
   then include the specific information from the RMIT sources that supports it.

   For questions beginning with "what", "how", "which", "when", or similar
   question words, answer the requested information directly.
   Do not begin these answers with "Yes" or "No".

   Make sure the answer does not contradict the evidence.

7. Before responding, check that your answer does not contradict any explicit
   statement in the provided information.

8. Only abstain if none of the provided passages contain enough information
   to answer the question.

   If there is not enough information, respond exactly with:
   "{ABSTENTION_TEXT}"

9. ANSWER DIRECTLY AND CONCISELY
   Answer in one or two complete sentences where possible.

   Include enough information to fully answer the question, but do not add
   unnecessary details.

   Do not explain your reasoning process or describe how you found the answer.
   Do not use phrases such as:
   "Based on the information provided",
   "According to the provided information",
   or "To determine this".

10. Do not invent, assume, predict, calculate, or add information that is not
    supported by the RMIT information below.

Question:
{question}

RMIT information:
{context}

Answer:
"""

def generate_answer(question, model=GENERATOR_MODEL, k=TOP_K):
    retrieved = retrieve_top_k(question, k=k)
    context_passages = [item["passage"] for item in retrieved]

    response = ollama.chat(
        model=model,
        messages=[{
            "role": "user",
            "content": build_prompt(question, context_passages)
        }],
        options={
            "temperature": 0.0,
            "num_ctx": 4096
        }
    )

    return {
        "answer": response["message"]["content"].strip(),
        "retrieval_context": context_passages,
        "retrieved_passage_ids": [item["passage_id"] for item in retrieved]
    }

# %% [markdown]
# ## 2. Build a small stratified sample

# %%
qrel_question_ids = set(qrels["question_id"])

deepeval_pool = topics[
    (topics["status"] == "known") &
    (topics["question_id"].isin(qrel_question_ids))
].copy()

print("Eligible questions per persona:")
display(deepeval_pool["persona"].value_counts())

deepeval_sample = (
    deepeval_pool
    .groupby("persona", group_keys=False)
    .sample(
        n=DEEPEVAL_PER_PERSONA,
        random_state=RANDOM_STATE
    )
    .reset_index(drop=True)
)

display(
    deepeval_sample[
        ["question_id", "persona", "question"]
    ].sort_values(["persona", "question_id"])
)

print("DeepEval sample size:", len(deepeval_sample))
# Out:
# Eligible questions per persona:
# persona
# prospective student    20
# current student        19
# parent/guardian        13
# Name: count, dtype: int64
#    question_id              persona  \
# 0       C01Q02      current student
# 3       C02Q02      current student
# 1       C06Q02      current student
# 2       C20Q01      current student
# 7       C17Q02      parent/guardian
# 6       C24Q01      parent/guardian
# 5       C25Q01      parent/guardian
# 4       C51Q01      parent/guardian
# 10      C05Q01  prospective student
# 8       C08Q01  prospective student
# 11      C09Q01  prospective student
# 9       C42Q01  prospective student
#
#                                                                                                                question
# 0                                                                    Is there an online version of the Business degree?
# 3                                                            What jobs can students expect after majoring in Marketing?
# 1                                          What jobs can I pursue after graduating from the Bachelor of Graphic Design?
# 2                                               How can I structure my degree part-time if I plan on working part time?
# 7                                  Can a student switch majors halfway through the Bachelor of Laws + Commerce program?
# 6                                                                          How much does the Bachelor of Business cost?
# 5                                            What computer specifications will my child need for the Bachelor of games?
# 4                                               Will my child have opportunities to work on real-world design projects?
# 10                                                     What majors can I choose from in the Bachelor of Graphic Design?
# 8                                                                 What are the prerequisites for the Bachelor of Games?
# 11  Do I need a background in animation or games to get into the Master of Animation, Games, and Interactivity program?
# 9                                              How long does the online Bachelor of Business take if I study part-time?
# DeepEval sample size: 12

# %% [markdown]
# ## 3. Generate answers first
#
# This is separate from judging so you do not need to regenerate answers if DeepEval is interrupted.

# %%
generation_rows = []

for i, row in deepeval_sample.iterrows():
    print(
        f"[{i + 1}/{len(deepeval_sample)}] "
        f"Generating {row['question_id']}..."
    )

    result = generate_answer(row["question"])

    generation_rows.append({
        "question_id": row["question_id"],
        "persona": row["persona"],
        "question": row["question"],
        "answer": result["answer"],
        "retrieved_passage_ids": result["retrieved_passage_ids"],
        "retrieval_context": result["retrieval_context"]
    })

    pd.DataFrame(generation_rows).to_pickle(
        "generation_results_progress.pkl"
    )

generation_results = pd.DataFrame(generation_rows)

display(
    generation_results[
        ["question_id", "persona", "question", "answer", "retrieved_passage_ids"]
    ]
)

print("Generation complete.")
# Out:
# [1/12] Generating C01Q02...
# [2/12] Generating C06Q02...
# [3/12] Generating C20Q01...
# [4/12] Generating C02Q02...
# [5/12] Generating C51Q01...
# [6/12] Generating C25Q01...
# [7/12] Generating C24Q01...
# [8/12] Generating C17Q02...
# [9/12] Generating C08Q01...
# [10/12] Generating C42Q01...
# [11/12] Generating C05Q01...
# [12/12] Generating C09Q01...
#    question_id              persona  \
# 0       C01Q02      current student
# 1       C06Q02      current student
# 2       C20Q01      current student
# 3       C02Q02      current student
# 4       C51Q01      parent/guardian
# 5       C25Q01      parent/guardian
# 6       C24Q01      parent/guardian
# 7       C17Q02      parent/guardian
# 8       C08Q01  prospective student
# 9       C42Q01  prospective student
# 10      C05Q01  prospective student
# 11      C09Q01  prospective student
#
#                                                                                                                question  \
# 0                                                                    Is there an online version of the Business degree?
# 1                                          What jobs can I pursue after graduating from the Bachelor of Graphic Design?
# 2                                               How can I structure my degree part-time if I plan on working part time?
# 3                                                            What jobs can students expect after majoring in Marketing?
# 4                                               Will my child have opportunities to work on real-world design projects?
# 5                                            What computer specifications will my child need for the Bachelor of games?
# 6                                                                          How much does the Bachelor of Business cost?
# 7                                  Can a student switch majors halfway through the Bachelor of Laws + Commerce program?
# 8                                                                 What are the prerequisites for the Bachelor of Games?
# 9                                              How long does the online Bachelor of Business take if I study part-time?
# 10                                                     What majors can I choose from in the Bachelor of Graphic Design?
# 11  Do I need a background in animation or games to get into the Master of Animation, Games, and Interactivity program?
#
#                                                                                                                                          answer  \
# 0    Yes, there is an online version of the Business degree, specifically the Bachelor of Business, which is available to study online at RMIT.
# 1   After graduating from the Bachelor of Graphic Design, you can pursue careers such as graphic designer, UX/UI designer, brand designer, i...
# 2   To structure your degree part-time while working part-time, you can complete four courses per year over six years, as part-time students...
# 3   Students majoring in Marketing can expect roles in digital marketing, brand management, campaign strategy, and customer analytics across...
# 4   Your child will have opportunities to work on real-world design projects through the Bachelor of Graphic Design, which includes industry...
# 5                                                         I don't have enough information in the provided RMIT sources to answer this question.
# 6                                                            The cost of the Bachelor of Business is not specified in the provided information.
# 7   A student cannot switch majors halfway through the Bachelor of Laws + Commerce program. This is because, once a student has commenced th...
# 8                  To be eligible for the Bachelor of Games, applicants must complete a selection task, which is a requirement for the program.
# 9                                                           The online Bachelor of Business takes 36 months to complete if you study part-time.
# 10                You can choose from four majors in the Bachelor of Graphic Design: Experience Design, Branding, Illustration, and Typography.
# 11  You do not need a background in animation or games to get into the Master of Animation, Games, and Interactivity program, as applicants ...
#
#    retrieved_passage_ids
# 0        [P01, P16, P44]
# 1        [P41, P06, P14]
# 2        [P15, P27, P35]
# 3        [P02, P04, P44]
# 4        [P24, P37, P36]
# 5        [P18, P33, P07]
# 6        [P14, P32, P44]
# 7        [P26, P27, P25]
# 8        [P18, P03, P17]
# 9        [P15, P03, P01]
# 10       [P40, P06, P41]
# 11       [P28, P18, P04]
# Generation complete.

# %% [markdown]
# # Part C — DeepEval

# %%
from deepeval.models import OllamaModel
from deepeval.metrics import AnswerRelevancyMetric, FaithfulnessMetric
from deepeval.test_case import LLMTestCase

judge_model = OllamaModel(
    model=JUDGE_MODEL,   
    base_url="http://localhost:11434",
    temperature=0
)

answer_relevancy_metric = AnswerRelevancyMetric(
    threshold=0.5,
    model=judge_model,
    include_reason=False,
    async_mode=True
)

faithfulness_metric = FaithfulnessMetric(
    threshold=0.5,
    model=judge_model,
    include_reason=False,
    async_mode=False
)

print("DeepEval judge:", JUDGE_MODEL)
# Out:
# DeepEval judge: qwen3:1.7b

# %% [markdown]
# ## 4. Answer Relevancy

# %%
relevancy_rows = []

for i, row in generation_results.iterrows():
    print(
        f"[{i + 1}/{len(generation_results)}] "
        f"Answer Relevancy — {row['question_id']}"
    )

    test_case = LLMTestCase(
        input=row["question"],
        actual_output=row["answer"]
    )

    try:
        answer_relevancy_metric.measure(test_case)
        score = answer_relevancy_metric.score
        error = None

    except Exception as e:
        score = np.nan
        error = str(e)

    relevancy_rows.append({
        "question_id": row["question_id"],
        "answer_relevancy": score,
        "relevancy_error": error
    })

    pd.DataFrame(relevancy_rows).to_csv(
        "deepeval_relevancy_progress.csv",
        index=False
    )

    print(f"Score: {score}")

relevancy_results = pd.DataFrame(relevancy_rows)

display(relevancy_results)
# Out:
# Output()
# [1/12] Answer Relevancy — C01Q02
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [2/12] Answer Relevancy — C06Q02
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [3/12] Answer Relevancy — C20Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [4/12] Answer Relevancy — C02Q02
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [5/12] Answer Relevancy — C51Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [6/12] Answer Relevancy — C25Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [7/12] Answer Relevancy — C24Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [8/12] Answer Relevancy — C17Q02
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [9/12] Answer Relevancy — C08Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [10/12] Answer Relevancy — C42Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: nan
# [11/12] Answer Relevancy — C05Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [12/12] Answer Relevancy — C09Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Score: 0.5
#    question_id  answer_relevancy  \
# 0       C01Q02               1.0
# 1       C06Q02               1.0
# 2       C20Q01               1.0
# 3       C02Q02               1.0
# 4       C51Q01               1.0
# 5       C25Q01               1.0
# 6       C24Q01               1.0
# 7       C17Q02               1.0
# 8       C08Q01               1.0
# 9       C42Q01               NaN
# 10      C05Q01               1.0
# 11      C09Q01               0.5
#
#                                                                                                                                 relevancy_error
# 0                                                                                                                                           NaN
# 1                                                                                                                                           NaN
# 2                                                                                                                                           NaN
# 3                                                                                                                                           NaN
# 4                                                                                                                                           NaN
# 5                                                                                                                                           NaN
# 6                                                                                                                                           NaN
# 7                                                                                                                                           NaN
# 8                                                                                                                                           NaN
# 9   1 validation error for Statements\n  Invalid JSON: EOF while parsing a value at line 1 column 0 [type=json_invalid, input_value='', inpu...
# 10                                                                                                                                          NaN
# 11                                                                                                                                          NaN

# %% [markdown]
# ## 5. Faithfulness

# %%
faithfulness_rows = []

for i, row in generation_results.iterrows():
    print(
        f"[{i + 1}/{len(generation_results)}] "
        f"Faithfulness — {row['question_id']}"
    )

    test_case = LLMTestCase(
        input=row["question"],
        actual_output=row["answer"],
        retrieval_context=row["retrieval_context"]
    )

    try:
        faithfulness_metric.measure(test_case)
        score = faithfulness_metric.score
        error = None
    except Exception as e:
        score = np.nan
        error = str(e)

    faithfulness_rows.append({
        "question_id": row["question_id"],
        "faithfulness": score,
        "faithfulness_error": error
    })

    pd.DataFrame(faithfulness_rows).to_csv(
        "deepeval_faithfulness_progress.csv",
        index=False
    )

    print(f"Score: {score}")

faithfulness_results = pd.DataFrame(faithfulness_rows)
display(faithfulness_results)
# Out:
# Output()
# [1/12] Faithfulness — C01Q02
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [2/12] Faithfulness — C06Q02
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [3/12] Faithfulness — C20Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [4/12] Faithfulness — C02Q02
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [5/12] Faithfulness — C51Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [6/12] Faithfulness — C25Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 0.0
# [7/12] Faithfulness — C24Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [8/12] Faithfulness — C17Q02
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [9/12] Faithfulness — C08Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [10/12] Faithfulness — C42Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 0.0
# [11/12] Faithfulness — C05Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Score: 1.0
# [12/12] Faithfulness — C09Q01
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Score: 1.0
#    question_id  faithfulness faithfulness_error
# 0       C01Q02           1.0               None
# 1       C06Q02           1.0               None
# 2       C20Q01           1.0               None
# 3       C02Q02           1.0               None
# 4       C51Q01           1.0               None
# 5       C25Q01           0.0               None
# 6       C24Q01           1.0               None
# 7       C17Q02           1.0               None
# 8       C08Q01           1.0               None
# 9       C42Q01           0.0               None
# 10      C05Q01           1.0               None
# 11      C09Q01           1.0               None

# %%
for qid in ["C01Q02", "C06Q02", "C02Q02", "C20Q01", "C51Q01", "C25Q01", "C24Q01", "C17Q02",
            "C08Q01", "C42Q01", "C05Q01", "C09Q01"]:
    row = generation_results[
        generation_results["question_id"] == qid
    ].iloc[0]

    print("\nQUESTION:", qid)
    print(row["question"])

    print("\nANSWER:")
    print(row["answer"])

    print("\nRETRIEVAL CONTEXT:")
    for passage in row["retrieval_context"]:
        print("-", passage)

    print("\n" + "=" * 80)
# Out:
# QUESTION: C01Q02
# Is there an online version of the Business degree?
#
# ANSWER:
# Yes, there is an online version of the Business degree, specifically the Bachelor of Business, which is available to study online at RMIT.
#
# RETRIEVAL CONTEXT:
# - The Bachelor of Business is available to study online at RMIT. The online Bachelor of Business takes 36 months to complete and offers flexible online learning in small cohorts of around 25 students with support from an Online Facilitator. The online degree is not available to international students intending to study on a student visa.
# - The expected study commitment for the online Bachelor of Business is approximately 10 to 12 hours per week for each subject. Each online term runs for 10 weeks.
# - When you successfully complete the Bachelor of Business, you may be eligible for entry into an RMIT Honours or postgraduate degree. You may be eligible for entry into the Master of Commerce after successfully completing the Bachelor of Business.
#
# ================================================================================
#
# QUESTION: C06Q02
# What jobs can I pursue after graduating from the Bachelor of Graphic Design?
#
# ANSWER:
# After graduating from the Bachelor of Graphic Design, you can pursue careers such as graphic designer, UX/UI designer, brand designer, illustrator, publication/editorial designer, and creative roles in agencies or in-house design teams.
#
# RETRIEVAL CONTEXT:
# - Graduates for Bachelor of Graphic design can pursue careers including graphic designer, UX/UI designer, brand designer, illustrator, publication/editorial designer, and creative roles in agencies or in-house design teams.
# - Graduates of the Bachelor of Graphic Design can pursue careers including communication designer, creative director, graphic designer, illustrator, service designer, and user experience designer. The individual majors also provide pathways to roles such as brand strategist, visual identity designer, UX/UI designer, interaction designer, concept artist, visual storyteller, book designer, publication designer, and specialist typographer.
# - The Business Information Systems major in the Bachelor of Business does not accommodate a second major because of its course structure. Students choosing Business Information Systems can instead pursue a second minor to broaden their studies.
#
# ================================================================================
#
# QUESTION: C02Q02
# What jobs can students expect after majoring in Marketing?
#
# ANSWER:
# Students majoring in Marketing can expect roles in digital marketing, brand management, campaign strategy, and customer analytics across industries like retail, advertising, technology, and consumer goods, with entry-level salaries starting around AU$70,000 and rising to AU$100,000+ for senior roles like marketing manager.
#
# RETRIEVAL CONTEXT:
# - The Marketing major prepares graduates for roles in digital marketing, brand management, campaign strategy, and customer analytics across industries like retail, advertising, technology, and consumer goods. Entry-level salaries start around AU$70,000, rising to AU$100,000+ for senior roles like marketing manager. The major is AMI-accredited, offering a faster path to Certified Practising Marketer (CPM) status and recognition from the UK's Chartered Institute of Marketing.
# - When you successfully complete this degree, you may be eligible for entry into a range of RMIT Honours and postgraduate qualifications in related business and commerce disciplines. These include: Master's degrees, such as the Master of Commerce, Master of Analytics, Master of Data Science, Master of Business Analytics and AI Strategy, Master of Finance, Master of Business Administration, Master of Marketing, Master of International Business, and Master of Professional Accounting, among others. Graduate Diplomas, such as the Graduate Diploma in Project Management. Graduate Certificates are shorter (typically 6-month full-time) qualifications in areas like Commerce, Analytics, Business Information Technology, Digital Economy, Finance, Marketing, and HR Management.
# - When you successfully complete the Bachelor of Business, you may be eligible for entry into an RMIT Honours or postgraduate degree. You may be eligible for entry into the Master of Commerce after successfully completing the Bachelor of Business.
#
# ================================================================================
#
# QUESTION: C20Q01
# How can I structure my degree part-time if I plan on working part time?
#
# ANSWER:
# To structure your degree part-time while working part-time, you can complete four courses per year over six years, as part-time students in the Bachelor of Business online.
#
# RETRIEVAL CONTEXT:
# - Students studying the Bachelor of Business online can choose between full-time and part-time study. The degree contains 24 courses. Full-time students complete eight courses per year over three years, while part-time students may complete four courses per year over six years.
# - The Bachelor of Laws/Bachelor of Commerce dual program has a total duration of 5 years full-time, or 10 years part-time.
# - Students in the Bachelor of Design Games may switch to a part-time study load at any point in their course.
#
# ================================================================================
#
# QUESTION: C51Q01
# Will my child have opportunities to work on real-world design projects?
#
# ANSWER:
# Your child will have opportunities to work on real-world design projects through the Bachelor of Graphic Design, which includes industry-partnered studio projects and collaborations with companies such as Penguin Books, Deloitte, and ABC.
#
# RETRIEVAL CONTEXT:
# - The Bachelor of Graphic Design has a strong focus on studio learning, enabling students to learn by doing. Throughout the degree, students respond to design briefs, develop and test ideas through making and iteration, present and critique their work, and build a professional portfolio. Industry is embedded throughout the course, with opportunities to work on industry-partnered studio projects and build real-world experience through projects with industry partners including Penguin Books, Deloitte, ABC, MECCA and Unisuper.
# - Students in the Bachelor of Games at RMIT are linked to industry-connected projects and practical studio learning, including collaborative projects and publicly showcased final-year work.
# - Students in the Bachelor of Games work through studio projects involving game design, mechanics, systems, game art, asset creation, game engines, prototyping and collaborative production.
#
# ================================================================================
#
# QUESTION: C25Q01
# What computer specifications will my child need for the Bachelor of games?
#
# ANSWER:
# I don't have enough information in the provided RMIT sources to answer this question.
#
# RETRIEVAL CONTEXT:
# - Applicants to the Master of Animation, Games and Interactivity normally need to complete and submit a selection task. However, graduates of RMIT's Bachelor of Design (Games), Bachelor of Design (Animation and Interactive Media), or Bachelor of Design (Digital Media) with a minimum overall GPA of 3.0 out of 4.0 are exempt from the selection task requirement. Graduates of the RMIT Graduate Certificate in Animation, Games and Interactivity are also exempt.
# - RMIT provides students specialist computer labs featuring art workstations, collaboration spaces, an Esports streaming lab, and dual-screen workstations for programming and working in game engines simultaneously. Students will be encouraged to use industry standard 3D modelling software such as Blender and Maya.
# - The Bachelor of Design (Games) provides specialist training in computer-generated design, with particular emphasis on game studies and art practice. Students develop skills across design, narrative, imaging, modelling and animation in 2D and 3D, concept art, and game environments.
#
# ================================================================================
#
# QUESTION: C24Q01
# How much does the Bachelor of Business cost?
#
# ANSWER:
# The cost of the Bachelor of Business is not specified in the provided information.
#
# RETRIEVAL CONTEXT:
# - The Business Information Systems major in the Bachelor of Business does not accommodate a second major because of its course structure. Students choosing Business Information Systems can instead pursue a second minor to broaden their studies.
# - The Bachelor of Business does not require students to choose a major. Students who do not select a major instead complete their study across the wider range of business and cross-disciplinary elective subjects available in the program.
# - When you successfully complete the Bachelor of Business, you may be eligible for entry into an RMIT Honours or postgraduate degree. You may be eligible for entry into the Master of Commerce after successfully completing the Bachelor of Business.
#
# ================================================================================
#
# QUESTION: C17Q02
# Can a student switch majors halfway through the Bachelor of Laws + Commerce program?
#
# ANSWER:
# A student cannot switch majors halfway through the Bachelor of Laws + Commerce program. This is because, once a student has commenced their major, they cannot change to a different major, as advised by course advisors.
#
# RETRIEVAL CONTEXT:
# - In the Bachelor of Laws/Bachelor of Commerce dual program, once a student has commenced their major, they cannot change to a different major. Students are advised to consult a course advisor before selecting a major.
# - The Bachelor of Laws/Bachelor of Commerce dual program has a total duration of 5 years full-time, or 10 years part-time.
# - The Bachelor of Laws/Bachelor of Commerce dual program is designed so students take a mix of both Law and Commerce subjects across their semesters, with an equal distribution of law and commerce courses in each semester, rather than completing one degree before starting the other.
#
# ================================================================================
#
# QUESTION: C08Q01
# What are the prerequisites for the Bachelor of Games?
#
# ANSWER:
# To be eligible for the Bachelor of Games, applicants must complete a selection task, which is a requirement for the program.
#
# RETRIEVAL CONTEXT:
# - Applicants to the Master of Animation, Games and Interactivity normally need to complete and submit a selection task. However, graduates of RMIT's Bachelor of Design (Games), Bachelor of Design (Animation and Interactive Media), or Bachelor of Design (Digital Media) with a minimum overall GPA of 3.0 out of 4.0 are exempt from the selection task requirement. Graduates of the RMIT Graduate Certificate in Animation, Games and Interactivity are also exempt.
# - At RMIT, you can take a third-year elective as a first-year student as long as you meet the course requirements and your program structure permits it. The RMIT Course Requisites policy states that Enrolment Online will block enrolment if a course has system-enforced prerequisites you haven't completed; however, if you have equivalent background knowledge, you can apply for an Enforced Requisite Waiver. If the elective lists only "Assumed Knowledge" rather than enforced prerequisites, you can self-enrol, though RMIT advises reviewing the Course Guide or contacting the Course Coordinator to ensure you can manage the course level.
# - Applicants to the Bachelor of Design (Games) are required to complete a selection task. The selection task asks applicants to complete one of the provided briefs and is used as part of the selection process. Most applicants can be selected on the basis of the selection task, with a folio presentation requested if further information is needed.
#
# ================================================================================
#
# QUESTION: C42Q01
# How long does the online Bachelor of Business take if I study part-time?
#
# ANSWER:
# The online Bachelor of Business takes 36 months to complete if you study part-time.
#
# RETRIEVAL CONTEXT:
# - Students studying the Bachelor of Business online can choose between full-time and part-time study. The degree contains 24 courses. Full-time students complete eight courses per year over three years, while part-time students may complete four courses per year over six years.
# - At RMIT, you can take a third-year elective as a first-year student as long as you meet the course requirements and your program structure permits it. The RMIT Course Requisites policy states that Enrolment Online will block enrolment if a course has system-enforced prerequisites you haven't completed; however, if you have equivalent background knowledge, you can apply for an Enforced Requisite Waiver. If the elective lists only "Assumed Knowledge" rather than enforced prerequisites, you can self-enrol, though RMIT advises reviewing the Course Guide or contacting the Course Coordinator to ensure you can manage the course level.
# - The Bachelor of Business is available to study online at RMIT. The online Bachelor of Business takes 36 months to complete and offers flexible online learning in small cohorts of around 25 students with support from an Online Facilitator. The online degree is not available to international students intending to study on a student visa.
#
# ================================================================================
#
# QUESTION: C05Q01
# What majors can I choose from in the Bachelor of Graphic Design?
#
# ANSWER:
# You can choose from four majors in the Bachelor of Graphic Design: Experience Design, Branding, Illustration, and Typography.
#
# RETRIEVAL CONTEXT:
# - The majors for the Bachelor of Graphic Design include Experience Design, Branding, Illustration, and Typography.
# - Graduates of the Bachelor of Graphic Design can pursue careers including communication designer, creative director, graphic designer, illustrator, service designer, and user experience designer. The individual majors also provide pathways to roles such as brand strategist, visual identity designer, UX/UI designer, interaction designer, concept artist, visual storyteller, book designer, publication designer, and specialist typographer.
# - Graduates for Bachelor of Graphic design can pursue careers including graphic designer, UX/UI designer, brand designer, illustrator, publication/editorial designer, and creative roles in agencies or in-house design teams.
#
# ================================================================================
#
# QUESTION: C09Q01
# Do I need a background in animation or games to get into the Master of Animation, Games, and Interactivity program?
#
# ANSWER:
# You do not need a background in animation or games to get into the Master of Animation, Games, and Interactivity program, as applicants with a successful completion of an Australian Bachelor degree (or equivalent overseas qualification) in any field are eligible.
#
# RETRIEVAL CONTEXT:
# - Entry to the Master of Animation, Games and Interactivity does not require a prior background specifically in animation or games. Applicants are eligible with successful completion of an Australian Bachelor degree (or equivalent overseas qualification) in any field, or alternatively at least three years of professional experience in the animation, games, interactivity or digital media area.
# - Applicants to the Master of Animation, Games and Interactivity normally need to complete and submit a selection task. However, graduates of RMIT's Bachelor of Design (Games), Bachelor of Design (Animation and Interactive Media), or Bachelor of Design (Digital Media) with a minimum overall GPA of 3.0 out of 4.0 are exempt from the selection task requirement. Graduates of the RMIT Graduate Certificate in Animation, Games and Interactivity are also exempt.
# - When you successfully complete this degree, you may be eligible for entry into a range of RMIT Honours and postgraduate qualifications in related business and commerce disciplines. These include: Master's degrees, such as the Master of Commerce, Master of Analytics, Master of Data Science, Master of Business Analytics and AI Strategy, Master of Finance, Master of Business Administration, Master of Marketing, Master of International Business, and Master of Professional Accounting, among others. Graduate Diplomas, such as the Graduate Diploma in Project Management. Graduate Certificates are shorter (typically 6-month full-time) qualifications in areas like Commerce, Analytics, Business Information Technology, Digital Economy, Finance, Marketing, and HR Management.
#
# ================================================================================

# %% [markdown]
# ## 6. Combine and summarise

# %%
deepeval_results = (
    generation_results
    .merge(relevancy_results, on="question_id", how="left")
    .merge(faithfulness_results, on="question_id", how="left")
)

display(
    deepeval_results[
        [
            "question_id",
            "persona",
            "question",
            "answer",
            "answer_relevancy",
            "faithfulness"
        ]
    ]
)
# Out:
#    question_id              persona  \
# 0       C01Q02      current student
# 1       C06Q02      current student
# 2       C20Q01      current student
# 3       C02Q02      current student
# 4       C51Q01      parent/guardian
# 5       C25Q01      parent/guardian
# 6       C24Q01      parent/guardian
# 7       C17Q02      parent/guardian
# 8       C08Q01  prospective student
# 9       C42Q01  prospective student
# 10      C05Q01  prospective student
# 11      C09Q01  prospective student
#
#                                                                                                                question  \
# 0                                                                    Is there an online version of the Business degree?
# 1                                          What jobs can I pursue after graduating from the Bachelor of Graphic Design?
# 2                                               How can I structure my degree part-time if I plan on working part time?
# 3                                                            What jobs can students expect after majoring in Marketing?
# 4                                               Will my child have opportunities to work on real-world design projects?
# 5                                            What computer specifications will my child need for the Bachelor of games?
# 6                                                                          How much does the Bachelor of Business cost?
# 7                                  Can a student switch majors halfway through the Bachelor of Laws + Commerce program?
# 8                                                                 What are the prerequisites for the Bachelor of Games?
# 9                                              How long does the online Bachelor of Business take if I study part-time?
# 10                                                     What majors can I choose from in the Bachelor of Graphic Design?
# 11  Do I need a background in animation or games to get into the Master of Animation, Games, and Interactivity program?
#
#                                                                                                                                          answer  \
# 0    Yes, there is an online version of the Business degree, specifically the Bachelor of Business, which is available to study online at RMIT.
# 1   After graduating from the Bachelor of Graphic Design, you can pursue careers such as graphic designer, UX/UI designer, brand designer, i...
# 2   To structure your degree part-time while working part-time, you can complete four courses per year over six years, as part-time students...
# 3   Students majoring in Marketing can expect roles in digital marketing, brand management, campaign strategy, and customer analytics across...
# 4   Your child will have opportunities to work on real-world design projects through the Bachelor of Graphic Design, which includes industry...
# 5                                                         I don't have enough information in the provided RMIT sources to answer this question.
# 6                                                            The cost of the Bachelor of Business is not specified in the provided information.
# 7   A student cannot switch majors halfway through the Bachelor of Laws + Commerce program. This is because, once a student has commenced th...
# 8                  To be eligible for the Bachelor of Games, applicants must complete a selection task, which is a requirement for the program.
# 9                                                           The online Bachelor of Business takes 36 months to complete if you study part-time.
# 10                You can choose from four majors in the Bachelor of Graphic Design: Experience Design, Branding, Illustration, and Typography.
# 11  You do not need a background in animation or games to get into the Master of Animation, Games, and Interactivity program, as applicants ...
#
#     answer_relevancy  faithfulness
# 0                1.0           1.0
# 1                1.0           1.0
# 2                1.0           1.0
# 3                1.0           1.0
# 4                1.0           1.0
# 5                1.0           0.0
# 6                1.0           1.0
# 7                1.0           1.0
# 8                1.0           1.0
# 9                NaN           0.0
# 10               1.0           1.0
# 11               0.5           1.0

# %%
deepeval_summary = pd.DataFrame({
    "metric": ["Answer Relevancy", "Faithfulness"],
    "score": [
        deepeval_results["answer_relevancy"].mean(),
        deepeval_results["faithfulness"].mean()
    ]
})

display(deepeval_summary.round(3))
# Out:
#              metric  score
# 0  Answer Relevancy  0.955
# 1      Faithfulness  0.833

# %%
deepeval_by_persona = (
    deepeval_results
    .groupby("persona")[["answer_relevancy", "faithfulness"]]
    .mean()
    .round(3)
)

display(deepeval_by_persona)
# Out:
#                      answer_relevancy  faithfulness
# persona
# current student                 1.000          1.00
# parent/guardian                 1.000          0.75
# prospective student             0.833          0.75

# %%
weak_cases = deepeval_results[
    (deepeval_results["answer_relevancy"] <= 0.5) |
    (deepeval_results["faithfulness"] <= 0.5)
].copy()

display(
    weak_cases[
        [
            "question_id",
            "persona",
            "question",
            "answer",
            "retrieved_passage_ids",
            "answer_relevancy",
            "faithfulness"
        ]
    ]
)

print("Weak cases:", len(weak_cases))
# Out:
#    question_id              persona  \
# 5       C25Q01      parent/guardian
# 9       C42Q01  prospective student
# 11      C09Q01  prospective student
#
#                                                                                                                question  \
# 5                                            What computer specifications will my child need for the Bachelor of games?
# 9                                              How long does the online Bachelor of Business take if I study part-time?
# 11  Do I need a background in animation or games to get into the Master of Animation, Games, and Interactivity program?
#
#                                                                                                                                          answer  \
# 5                                                         I don't have enough information in the provided RMIT sources to answer this question.
# 9                                                           The online Bachelor of Business takes 36 months to complete if you study part-time.
# 11  You do not need a background in animation or games to get into the Master of Animation, Games, and Interactivity program, as applicants ...
#
#    retrieved_passage_ids  answer_relevancy  faithfulness
# 5        [P18, P33, P07]               1.0           0.0
# 9        [P15, P03, P01]               NaN           0.0
# 11       [P28, P18, P04]               0.5           1.0
# Weak cases: 3

# %%
export_df = deepeval_results.copy()

export_df["retrieved_passage_ids"] = export_df[
    "retrieved_passage_ids"
].apply(lambda x: " | ".join(map(str, x)))

export_df["retrieval_context"] = export_df[
    "retrieval_context"
].apply(lambda x: " ||| ".join(map(str, x)))

export_df.to_csv("deepeval_results.csv", index=False)
deepeval_summary.to_csv("deepeval_summary.csv", index=False)
deepeval_by_persona.to_csv("deepeval_by_persona.csv")

print("DeepEval results saved.")
# Out:
# DeepEval results saved.

# %% [markdown]
# ## Preliminary Evaluation Summary
#
# The preliminary evaluation indicates that the RAG system performs reasonably well overall, while also identifying areas for improvement in both retrieval and answer generation.
#
# ### Retrieval Performance
#
# Retrieval was evaluated across 53 questions using Hit@3, Recall@3, and NDCG@3. The system achieved:
#
# - **Hit@3 = 0.774**
# - **Recall@3 = 0.717**
# - **NDCG@3 = 0.686**
#
# The Hit@3 score indicates that at least one relevant passage was retrieved within the top three results for approximately 77% of evaluated questions. The lower Recall@3 score suggests that, although the system frequently retrieves relevant information, it does not always retrieve all relevant passages within the top three results. The NDCG@3 score of 0.686 further indicates that relevant passages are not always ranked in the optimal order.
#
# Performance also varied across personas. Current-student questions achieved the strongest retrieval performance (Hit@3 = 0.947, Recall@3 = 0.868, NDCG@3 = 0.850), while parent/guardian and prospective-student questions produced lower scores. Prospective-student questions had the lowest Hit@3 (0.667) and Recall@3 (0.619), suggesting that retrieval could be improved for questions relating to areas such as program requirements, course information, and career outcomes.
#
# ### Generation Performance
#
# DeepEval was applied to a stratified sample of 12 questions, with four questions selected from each persona. The system achieved:
#
# - **Answer Relevancy = 0.955**
# - **Faithfulness = 0.833**
#
# The high Answer Relevancy score suggests that generated responses generally addressed the user's question directly. Faithfulness was also relatively high, indicating that most answers were supported by the retrieved RMIT passages.
#
# However, individual failures demonstrate why retrieval and generation need to be evaluated separately. For example, for **C42Q01**, the correct passage was retrieved and stated that part-time Bachelor of Business students may complete the degree over six years. Despite this, the generated response incorrectly stated that part-time study takes 36 months. This represents a generation/faithfulness failure despite successful retrieval.
#
# DeepEval also assigned a faithfulness score of 0 to **C25Q01**, where the system abstained because the retrieved sources did not provide sufficient information about required computer specifications. Manual inspection suggests that this abstention was appropriate, highlighting that automated LLM-based evaluation scores should be interpreted alongside qualitative inspection rather than treated as definitive measures of answer quality.
#
# Generation performance also differed by persona. Current-student questions achieved perfect scores for both Answer Relevancy and Faithfulness in this sample, while parent/guardian and prospective-student questions showed weaker faithfulness (0.75 each). Prospective-student questions also had lower Answer Relevancy (0.833).
#
# ### Overall Interpretation
#
# Overall, the preliminary results suggest that the system is capable of producing highly relevant and generally well-grounded responses when suitable evidence is retrieved. However, retrieval remains the main area for improvement, particularly for prospective-student and parent/guardian questions. The results also demonstrate that successful retrieval does not guarantee a correct generated answer, as the model may select or interpret retrieved evidence incorrectly.
#
# These findings support the use of a multi-layer evaluation framework combining **retrieval metrics (Hit@3, Recall@3 and NDCG@3)** with **generation metrics (Answer Relevancy and Faithfulness)** and manual failure analysis. Future improvements should focus on improving retrieval coverage and ranking, reducing conflicting or irrelevant retrieved passages, and strengthening the generation stage so that answers prioritise the most relevant evidence in the retrieved context.
#
# As this is a preliminary evaluation using a limited DeepEval sample of 12 questions, the generation results should be interpreted as indicative rather than as a definitive estimate of system performance.
